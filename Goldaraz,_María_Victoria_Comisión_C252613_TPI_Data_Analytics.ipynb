# %% [markdown]
# <a href="https://colab.research.google.com/github/VictoriaGoldaraz/TT-2C2025-Data-Analitycs-Notebooks/blob/main/Goldaraz%2C_Mar%C3%ADa_Victoria_Comisi%C3%B3n_C252613_TPI_Data_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ventas = [
  {'producto': 'notebook', 'precio': 1500.0, 'cantidad': 3},
  {'producto': 'monitor', 'precio': 500.0, 'cantidad': 5},
  {'producto': 'mouse', 'precio': 20.0, 'cantidad': 15}
]

# %%
total_ventas = 0
for venta in ventas:
  total_ventas += venta['precio'] * venta['cantidad']
print(total_ventas)
# Out:
# 7300.0

# %%
total_ventas = sum([venta['precio'] * venta['cantidad'] for venta in ventas])
print(total_ventas)
# Out:
# 7300.0

# %%
import pandas as pd

# %%
# Importación de github
df_ventas = pd.read_csv("https://raw.githubusercontent.com/jrigottiedu/TT-2C2025-Data-Analitycs-Notebooks/refs/heads/main/PreEntrega/Datasets/ventas.csv")

# %%
df_clientes = pd.read_csv("https://raw.githubusercontent.com/jrigottiedu/TT-2C2025-Data-Analitycs-Notebooks/refs/heads/main/PreEntrega/Datasets/clientes.csv")

# %%
df_marketing = pd.read_csv("https://raw.githubusercontent.com/jrigottiedu/TT-2C2025-Data-Analitycs-Notebooks/refs/heads/main/PreEntrega/Datasets/marketing.csv")

# %%
# Análisis de DF de Ventas
df_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3035 entries, 0 to 3034
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     3035 non-null   int64
#  1   producto     3035 non-null   object
#  2   precio       3033 non-null   object
#  3   cantidad     3033 non-null   float64
#  4   fecha_venta  3035 non-null   object
#  5   categoria    3035 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 142.4+ KB

# %%
df_ventas.head()
# Out:
#    id_venta           producto   precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   $69.94       5.0  02/01/2024
# 1       811    Lámpara de mesa  $105.10       5.0  02/01/2024
# 2      1156           Secadora   $97.96       3.0  02/01/2024
# 3      1372           Heladera  $114.35       8.0  02/01/2024
# 4      1546           Secadora  $106.21       4.0  02/01/2024
#
#            categoria
# 0         Decoración
# 1         Decoración
# 2  Electrodomésticos
# 3  Electrodomésticos
# 4  Electrodomésticos

# %%
df_ventas.describe()
# Out:
#           id_venta     cantidad
# count  3035.000000  3033.000000
# mean   1499.851400     6.496538
# std     866.465379     3.457250
# min       1.000000     1.000000
# 25%     748.500000     3.000000
# 50%    1502.000000     7.000000
# 75%    2249.500000     9.000000
# max    3000.000000    12.000000

# %%
df_ventas["producto"].unique()
# Out:
# array(['Cuadro decorativo', 'Lámpara de mesa', 'Secadora', 'Heladera',
#        'Horno eléctrico', 'Plancha de vapor', 'Proyector',
#        'Rincón de plantas', 'Candelabro', 'Aspiradora',
#        'Freidora eléctrica', 'Tablet', 'Cortinas', 'Adorno de pared',
#        'Jarrón decorativo', 'Lavadora', 'Auriculares', 'Cámara digital',
#        'Cafetera', 'Consola de videojuegos', 'Smartphone',
#        'Elementos de cerámica', 'Espejo decorativo',
#        'Parlantes Bluetooth', 'SmartWatch', 'Microondas', 'Batidora',
#        'Alfombra', 'Televisor', 'Laptop'], dtype=object)

# %%
df_ventas.sample(5)
# Out:
#       id_venta    producto   precio  cantidad fecha_venta          categoria
# 461       2419   Proyector   $52.52       3.0  23/02/2024        Electrónica
# 850       1776    Secadora   $33.55       3.0  06/04/2024  Electrodomésticos
# 1840      2439   Proyector   $59.08       3.0  01/08/2024        Electrónica
# 1498       625    Alfombra  $124.91       3.0  18/06/2024         Decoración
# 236       2323  Smartphone   $34.50       1.0  28/01/2024        Electrónica

# %%
df_ventas.duplicated().sum()
# Out:
# np.int64(35)

# %%
# visualizar duplicados
df_ventas[df_ventas.duplicated()]
# Out:
#      id_venta                producto   precio  cantidad fecha_venta  \
# 826        56                Cortinas   $66.24       5.0  05/04/2024
# 827       421         Lámpara de mesa  $114.83       9.0  05/04/2024
# 828       424       Jarrón decorativo   $87.94       2.0  05/04/2024
# 829      1868                Cafetera   $62.23       1.0  05/04/2024
# 830      2545             Auriculares   $32.81      11.0  05/04/2024
# 831      2778              SmartWatch   $70.66       7.0  05/04/2024
# 844       145                Alfombra   $41.72       8.0  06/04/2024
# 845       300         Adorno de pared   $67.75       9.0  06/04/2024
# 846       439         Lámpara de mesa   $35.43       2.0  06/04/2024
# 847       906                Cortinas   $84.04       3.0  06/04/2024
# 848       959         Lámpara de mesa   $76.32       7.0  06/04/2024
# 849      1376                Secadora   $69.58       7.0  06/04/2024
# 850      1776                Secadora   $33.55       3.0  06/04/2024
# ...

# %%
# Eliminar duplicados
df_ventas.drop_duplicates(inplace=True)

# %%
# Validar eliminacion de duplicados
df_ventas.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Buscar datos nulos
df_ventas.isnull().sum()
# Out:
# id_venta       0
# producto       0
# precio         2
# cantidad       2
# fecha_venta    0
# categoria      0
# dtype: int64

# %%
df_ventas[df_ventas.isnull().any(axis=1)]
# Out:
#      id_venta               producto precio  cantidad fecha_venta    categoria
# 136       627  Elementos de cerámica    NaN       NaN  17/01/2024   Decoración
# 139      2171    Parlantes Bluetooth    NaN       NaN  17/01/2024  Electrónica

# %%
df_ventas.dropna(inplace=True)

# %%
# Validar eliminación de datos nulos
df_ventas[df_ventas.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [id_venta, producto, precio, cantidad, fecha_venta, categoria]
# Index: []

# %%
# Reemplazar caracter especial $ con nada
df_ventas["precio"] = df_ventas["precio"].str.replace("$", "")

# %%
# Convertir tipo de precio a float
df_ventas["precio"] = df_ventas["precio"].astype(float)

# %%
# Validar tipo de precio
df_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2998 entries, 0 to 3034
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     2998 non-null   int64
#  1   producto     2998 non-null   object
#  2   precio       2998 non-null   float64
#  3   cantidad     2998 non-null   float64
#  4   fecha_venta  2998 non-null   object
#  5   categoria    2998 non-null   object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 164.0+ KB

# %%
# Formato de fecha
df_ventas["fecha_venta"] = pd.to_datetime(df_ventas["fecha_venta"], dayfirst=True)

# %%
# Validar formato de fecha
df_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2998 entries, 0 to 3034
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     2998 non-null   int64
#  1   producto     2998 non-null   object
#  2   precio       2998 non-null   float64
#  3   cantidad     2998 non-null   float64
#  4   fecha_venta  2998 non-null   datetime64[ns]
#  5   categoria    2998 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(2)
# memory usage: 164.0+ KB

# %%
# Análisis de DF de Marketing
df_marketing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_campanha   90 non-null     int64
#  1   producto      90 non-null     object
#  2   canal         90 non-null     object
#  3   costo         90 non-null     float64
#  4   fecha_inicio  90 non-null     object
#  5   fecha_fin     90 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.3+ KB

# %%
df_marketing.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_marketing.isnull().sum()
# Out:
# id_campanha     0
# producto        0
# canal           0
# costo           0
# fecha_inicio    0
# fecha_fin       0
# dtype: int64

# %%
df_marketing[df_marketing.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [id_campanha, producto, canal, costo, fecha_inicio, fecha_fin]
# Index: []

# %%
# Convertir fechas a datetime
df_marketing["fecha_inicio"] = pd.to_datetime(df_marketing["fecha_inicio"], dayfirst=True)
df_marketing["fecha_fin"] = pd.to_datetime(df_marketing["fecha_fin"], dayfirst=True)

# %%
# Validar tipo de fecha
df_marketing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_campanha   90 non-null     int64
#  1   producto      90 non-null     object
#  2   canal         90 non-null     object
#  3   costo         90 non-null     float64
#  4   fecha_inicio  90 non-null     datetime64[ns]
#  5   fecha_fin     90 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 4.3+ KB

# %%
# Analisis DF de Clientes
df_clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567 entries, 0 to 566
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_cliente  567 non-null    int64
#  1   nombre      567 non-null    object
#  2   edad        567 non-null    int64
#  3   ciudad      567 non-null    object
#  4   ingresos    567 non-null    float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 22.3+ KB

# %%
# Duplicados
df_clientes.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Nulos
df_clientes.isnull().sum()
# Out:
# id_cliente    0
# nombre        0
# edad          0
# ciudad        0
# ingresos      0
# dtype: int64

# %%
# Transformación
# Productos de alto rendimiento
# Nueva columna Total_venta
df_ventas["total_venta"] = df_ventas["precio"] * df_ventas["cantidad"]

# %%
df_ventas.head()
# Out:
#    id_venta           producto  precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   69.94       5.0  2024-01-02
# 1       811    Lámpara de mesa  105.10       5.0  2024-01-02
# 2      1156           Secadora   97.96       3.0  2024-01-02
# 3      1372           Heladera  114.35       8.0  2024-01-02
# 4      1546           Secadora  106.21       4.0  2024-01-02
#
#            categoria  total_venta
# 0         Decoración       349.70
# 1         Decoración       525.50
# 2  Electrodomésticos       293.88
# 3  Electrodomésticos       914.80
# 4  Electrodomésticos       424.84

# %%
# Ver cuáles son 3 productos que más ganaron
df_ventas.groupby("producto")["total_venta"].sum().sort_values(ascending=False).head(3)
# Out:
# producto
# Lámpara de mesa    82276.38
# Auriculares        74175.58
# Microondas         72562.89
# Name: total_venta, dtype: float64

# %%
# Agregación
# Resumir las ventas por categoría de producto y analizar los ingresos generados.
df_ventas.groupby("categoria")["total_venta"].sum()
# Out:
# categoria
# Decoración           479216.09
# Electrodomésticos    505299.63
# Electrónica          482577.80
# Name: total_venta, dtype: float64

# %%
# Integración de datos
# Combinar df_ventas y df_marketing por columna "producto"
df_ventas_marketing = pd.merge(df_ventas, df_marketing, on="producto")

# %%
df_ventas_marketing.head()
# Out:
#    id_venta           producto  precio  cantidad fecha_venta   categoria  \
# 0       792  Cuadro decorativo   69.94       5.0  2024-01-02  Decoración
# 1       792  Cuadro decorativo   69.94       5.0  2024-01-02  Decoración
# 2       792  Cuadro decorativo   69.94       5.0  2024-01-02  Decoración
# 3       811    Lámpara de mesa  105.10       5.0  2024-01-02  Decoración
# 4       811    Lámpara de mesa  105.10       5.0  2024-01-02  Decoración
#
#    total_venta  id_campanha  canal  costo fecha_inicio  fecha_fin
# 0        349.7            1   RRSS   5.27   2024-04-27 2024-06-04
# 1        349.7           31  Email   5.28   2024-08-15 2024-09-12
# 2        349.7           61     TV   5.30   2024-11-05 2024-12-23
# 3        525.5           32  Email   5.54   2024-03-28 2024-04-20
# 4        525.5            2   RRSS   5.88   2024-05-30 2024-06-29

# %% [markdown]
# Observaciones:
# *Dataframe Ventas:*
# 35 duplicados, eliminar
# Datos nulos 4, dos en precio y dos en cantidad, eliminar
# Eliminamos carácter $ en precio y convertimos tipo a float
# *Dataframe Markeging:*
# Sin duplicados
# Sin nulos
# Cambiar format de fechas
# *Dataframe Clientes:*
# Sin duplicados
# Sin nulos

# %%
#Modificación de  DF de VENTAS
#Primero hay que agregar otro valor numérico. Calcular el valor de cada venta. precio * cantidad
#Nueva columna venta_unitaria
df_ventas["venta_unitaria"] = df_ventas["precio"] * df_ventas["cantidad"]

# %%
#Visualizar
df_ventas.head(2)
# Out:
#    id_venta           producto  precio  cantidad fecha_venta   categoria  \
# 0       792  Cuadro decorativo   69.94       5.0  2024-01-02  Decoración
# 1       811    Lámpara de mesa  105.10       5.0  2024-01-02  Decoración
#
#    total_venta  venta_unitaria
# 0        349.7           349.7
# 1        525.5           525.5

# %%
df_ventas[["precio", "cantidad", "venta_unitaria"]].describe()
# Out:
#             precio     cantidad  venta_unitaria
# count  2998.000000  2998.000000     2998.000000
# mean     75.291318     6.502668      489.357412
# std      28.736008     3.455107      334.281817
# min      26.000000     1.000000       26.300000
# 25%      50.030000     3.000000      220.920000
# 50%      75.205000     7.000000      418.065000
# 75%     100.067500     9.000000      709.920000
# max     124.970000    12.000000     1488.120000

# %%
#Agragación:
tabla_ventas = (df_ventas.groupby("producto", as_index=False)["venta_unitaria"].sum())
tabla_ventas.head(3)
# Out:
#           producto  venta_unitaria
# 0  Adorno de pared        48093.49
# 1         Alfombra        44773.06
# 2       Aspiradora        50085.86

# %%
# Análisis estadístico

tabla_ventas.describe()
# Out:
#        venta_unitaria
# count       30.000000
# mean     48903.117333
# std      13265.561715
# min      11128.800000
# 25%      45601.920000
# 50%      48140.245000
# 75%      51092.960000
# max      82276.380000

# %%
#Gráficos de visualización
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(tabla_ventas["venta_unitaria"], bins=30, kde=True, edgecolor="black")
plt.title("Distribución de ventas con curva de densidad")
plt.xlabel("Ventas unitarias")
plt.ylabel("Frecuencia")
plt.show()

# %%
# Percentil 75

umbral_ventas = tabla_ventas["venta_unitaria"].quantile(0.75)
umbral_ventas
# Out:
# np.float64(51092.96)

# %%
# Identificar productos que superan el umbral
# productos_top = tabla_ventas.query("venta_unitaria" >= @umbral")
productos_top = tabla_ventas[tabla_ventas["venta_unitaria"] >= umbral_ventas]
productos_top
# Out:
#              producto  venta_unitaria
# 3         Auriculares        74175.58
# 5            Cafetera        59607.31
# 9   Cuadro decorativo        54297.60
# 16  Jarrón decorativo        51130.88
# 19    Lámpara de mesa        82276.38
# 20         Microondas        72562.89
# 25           Secadora        52115.45
# 27         Smartphone        54132.44

# %%
df_ventas.columns
# Out:
# Index(['id_venta', 'producto', 'precio', 'cantidad', 'fecha_venta',
#        'categoria', 'total_venta', 'venta_unitaria'],
#       dtype='object')

# %%
# Agrupar x categoría y sumamos
ventas_categoria = df_ventas.groupby("categoria", as_index=False)["venta_unitaria"].sum()
ventas_categoria.head()
# Out:
#            categoria  venta_unitaria
# 0         Decoración       479216.09
# 1  Electrodomésticos       505299.63
# 2        Electrónica       482577.80

# %%
# Integración
df_ventas.info()
df_marketing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2998 entries, 0 to 3034
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_venta        2998 non-null   int64
#  1   producto        2998 non-null   object
#  2   precio          2998 non-null   float64
#  3   cantidad        2998 non-null   float64
#  4   fecha_venta     2998 non-null   datetime64[ns]
#  5   categoria       2998 non-null   object
#  6   total_venta     2998 non-null   float64
#  7   venta_unitaria  2998 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(2)
# memory usage: 210.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_campanha   90 non-null     int64
#  1   producto      90 non-null     object
#  2   canal         90 non-null     object
# ...

# %%
# Unir DF de Ventas y Marketing
# Merge por producto
ventas_marketing = pd.merge(df_ventas, df_marketing, on="producto", how="left")
print("Cantidad de registros: ", len(ventas_marketing))
# Out:
# Cantidad de registros:  8994

# %%
# Visualización por producto e ID de venta
ventas_marketing[["id_venta","producto", "venta_unitaria", "canal", "costo", "fecha_venta", "fecha_inicio","fecha_fin"]].sort_values(by=["producto", "id_venta"], ascending=True).head(4)
# Out:
#       id_venta         producto  venta_unitaria  canal  costo fecha_venta  \
# 4602        10  Adorno de pared          446.50     TV   4.81  2024-06-29
# 4603        10  Adorno de pared          446.50  Email   5.08  2024-06-29
# 4604        10  Adorno de pared          446.50   RRSS   4.16  2024-06-29
# 303         20  Adorno de pared          180.42     TV   4.81  2024-01-14
#
#      fecha_inicio  fecha_fin
# 4602   2024-03-20 2024-05-03
# 4603   2024-04-13 2024-05-10
# 4604   2024-10-22 2024-12-21
# 303    2024-03-20 2024-05-03

# %%
# Visualizamos producto por fecha de venta
ventas_marketing[["id_venta","producto", "venta_unitaria", "canal", "costo", "fecha_venta", "fecha_inicio","fecha_fin"]].sort_values(by=["venta_unitaria"], ascending=False).head(10)
# Out:
#       id_venta    producto  venta_unitaria  canal  costo fecha_venta  \
# 1646      2063  Smartphone         1488.12     TV   4.78  2024-03-05
# 1644      2063  Smartphone         1488.12   RRSS   6.37  2024-03-05
# 1645      2063  Smartphone         1488.12  Email   4.65  2024-03-05
# 2625      1109    Batidora         1485.96  Email   4.48  2024-04-11
# 2627      1109    Batidora         1485.96   RRSS   4.52  2024-04-11
# 2626      1109    Batidora         1485.96     TV   6.28  2024-04-11
# 2538      2373  Smartphone         1483.20   RRSS   6.37  2024-04-07
# 2539      2373  Smartphone         1483.20  Email   4.65  2024-04-07
# 2540      2373  Smartphone         1483.20     TV   4.78  2024-04-07
# 6925      2703  Smartphone         1480.80  Email   4.65  2024-10-03
#
#      fecha_inicio  fecha_fin
# 1646   2024-09-28 2024-10-24
# 1644   2024-03-29 2024-05-16
# 1645   2024-05-28 2024-06-15
# 2625   2024-04-10 2024-06-08
# 2627   2024-11-01 2024-12-08
# ...

# %%
# Ventas dentro de la campaña
ventas_con_marketing = ventas_marketing.query("fecha_venta >= fecha_inicio & fecha_venta <= fecha_fin")
print("Cantidad de registros dentro de la campaña: ", len(ventas_con_marketing))
# Out:
# Cantidad de registros dentro de la campaña:  847

# %%
# Registros de ventas durante la campaña
ventas_con_marketing[["id_venta","producto", "venta_unitaria", "canal", "costo", "fecha_venta", "fecha_inicio","fecha_fin"]].sort_values(by=["producto", "id_venta"], ascending=True).head(6)
# Out:
#       id_venta         producto  venta_unitaria  canal  costo fecha_venta  \
# 7937        70  Adorno de pared         1265.04   RRSS   4.16  2024-11-18
# 3195       100  Adorno de pared          897.28     TV   4.81  2024-05-02
# 3196       100  Adorno de pared          897.28  Email   5.08  2024-05-02
# 8450       130  Adorno de pared          206.10   RRSS   4.16  2024-12-08
# 7508       190  Adorno de pared          360.80   RRSS   4.16  2024-10-30
# 2160       210  Adorno de pared          286.68     TV   4.81  2024-03-24
#
#      fecha_inicio  fecha_fin
# 7937   2024-10-22 2024-12-21
# 3195   2024-03-20 2024-05-03
# 3196   2024-04-13 2024-05-10
# 8450   2024-10-22 2024-12-21
# 7508   2024-10-22 2024-12-21
# 2160   2024-03-20 2024-05-03

# %%
# Visualización de duplicados
ventas_con_marketing_duplicados = ventas_con_marketing[ventas_con_marketing.duplicated(subset="id_venta",keep=False)]
ventas_con_marketing_duplicados[["id_venta","producto", "venta_unitaria", "canal", "costo", "fecha_venta", "fecha_inicio","fecha_fin"]].sort_values(by=["producto", "id_venta"], ascending=True).head(6)
# Out:
#       id_venta         producto  venta_unitaria  canal  costo fecha_venta  \
# 3195       100  Adorno de pared          897.28     TV   4.81  2024-05-02
# 3196       100  Adorno de pared          897.28  Email   5.08  2024-05-02
# 3237       220  Adorno de pared          498.24     TV   4.81  2024-05-03
# 3238       220  Adorno de pared          498.24  Email   5.08  2024-05-03
# 2985       320  Adorno de pared          224.28     TV   4.81  2024-04-25
# 2986       320  Adorno de pared          224.28  Email   5.08  2024-04-25
#
#      fecha_inicio  fecha_fin
# 3195   2024-03-20 2024-05-03
# 3196   2024-04-13 2024-05-10
# 3237   2024-03-20 2024-05-03
# 3238   2024-04-13 2024-05-10
# 2985   2024-03-20 2024-05-03
# 2986   2024-04-13 2024-05-10

# %%
# Agrupación por ID de venta y producto, y ver solo productos con id_venta único

ventas_con_marketing_agg1 = ventas_con_marketing.groupby(["id_venta","producto"], as_index=False).agg(
    venta_unitaria=("venta_unitaria", "first"),
    costo_agg=("costo", "sum")
)

print("Cantidad de registros con id_venta únicos: ", len(ventas_con_marketing_agg1))
# Out:
# Cantidad de registros con id_venta únicos:  768

# %%
# Verificación
ventas_con_marketing_agg1[["id_venta","producto", "venta_unitaria", "costo_agg"]].sort_values(by=["producto", "id_venta"], ascending=True).head(6)
# Out:
#     id_venta         producto  venta_unitaria  costo_agg
# 20        70  Adorno de pared         1265.04       4.16
# 30       100  Adorno de pared          897.28       9.89
# 39       130  Adorno de pared          206.10       4.16
# 56       190  Adorno de pared          360.80       4.16
# 61       210  Adorno de pared          286.68       4.81
# 64       220  Adorno de pared          498.24       9.89

# %%
# Agrupación por producto únicamente
ventas_con_marketing_agg2 = ventas_con_marketing_agg1.groupby(["producto"], as_index=False).agg(
    ventas_producto_cm=("venta_unitaria", "sum"),
    costo_marketing=("costo_agg", "sum")
)

# Agregamos columna con la ganancia
ventas_con_marketing_agg2["ganacia_producto_cm"]= ventas_con_marketing_agg2["ventas_producto_cm"]-ventas_con_marketing_agg2["costo_marketing"]

# Ordenamos y guardamos DF final
ventas_con_marketing_final = ventas_con_marketing_agg2.sort_values(by=["ganacia_producto_cm"], ascending=False)

# %%
# DF final
ventas_con_marketing_final.head(5)
# Out:
#                producto  ventas_producto_cm  costo_marketing  \
# 4              Batidora            23460.35           227.32
# 9     Cuadro decorativo            19293.71           195.51
# 3           Auriculares            18181.01           212.75
# 21  Parlantes Bluetooth            17942.96           144.45
# 19      Lámpara de mesa            17925.37           235.19
#
#     ganacia_producto_cm
# 4              23233.03
# 9              19098.20
# 3              17968.26
# 21             17798.51
# 19             17690.18

# %%
# Ventas fuera de la compaña
# Filtrado de productos vendidos fuera de campaña

ventas_sin_marketing = ventas_marketing.query("(fecha_venta < fecha_inicio) | (fecha_venta > fecha_fin)")
print("Cantidad de registros fuera de la campaña: ", len(ventas_sin_marketing))
# Out:
# Cantidad de registros fuera de la campaña:  8147

# %%
ventas_sin_marketing[["id_venta","producto", "venta_unitaria", "fecha_venta", "fecha_inicio","fecha_fin"]].sort_values(by=["id_venta","producto"], ascending=True).head(6)
# Out:
#       id_venta           producto  venta_unitaria fecha_venta fecha_inicio  \
# 2794         1    Lámpara de mesa          658.00  2024-04-17   2024-05-30
# 2795         1    Lámpara de mesa          658.00  2024-04-17   2024-08-26
# 1458         2  Cuadro decorativo          318.36  2024-02-27   2024-04-27
# 1459         2  Cuadro decorativo          318.36  2024-02-27   2024-08-15
# 1460         2  Cuadro decorativo          318.36  2024-02-27   2024-11-05
# 6630         3  Espejo decorativo           51.32  2024-09-22   2024-05-31
#
#       fecha_fin
# 2794 2024-06-29
# 2795 2024-10-07
# 1458 2024-06-04
# 1459 2024-09-12
# 1460 2024-12-23
# 6630 2024-07-08

# %%
# Resolver ID duplicados con filtro de agrupación
ventas_sin_marketing_agg1 = ventas_sin_marketing.groupby(["id_venta", "producto"], as_index=False).agg(
    venta_unitaria=("venta_unitaria", "first")
)
print(len(ventas_sin_marketing_agg1))
# Out:
# 2998

# %%
ventas_sin_marketing_agg2 = ventas_sin_marketing_agg1.groupby(["producto"], as_index=False).agg(
    ventas_producto_sm=("venta_unitaria", "sum")
)

# %%
# Guardamos DF final
ventas_sin_marketing_final = ventas_sin_marketing_agg2[["producto", "ventas_producto_sm"]].sort_values(by=["ventas_producto_sm"], ascending=False)

# %%
# Visualización
ventas_sin_marketing_final.head(5)
# Out:
#              producto  ventas_producto_sm
# 19    Lámpara de mesa            82276.38
# 3         Auriculares            74175.58
# 20         Microondas            72562.89
# 5            Cafetera            59607.31
# 9   Cuadro decorativo            54297.60

# %% [markdown]
# GRÁFICOS

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Gráfico de ventas y costos apilado para comparar el valor de ventas unitarias y costos por productos
# Estilos
sns.set_theme(
    style="whitegrid",
    palette="Set3",
    context="notebook")
plt.figure(figsize=(10,6))

# Primer nivel (abajo)
plt.bar(ventas_con_marketing_final["producto"], ventas_con_marketing_final["ventas_producto_cm"], label="Ventas")

# Segundo nivel (arriba)
plt.bar(ventas_con_marketing_final["producto"], ventas_con_marketing_final["costo_marketing"],
        bottom=ventas_con_marketing_final["ventas_producto_cm"],
        label="Costo Marketing")


plt.xticks(rotation=90, fontsize=8)
plt.yticks(fontsize=8)
plt.show()

# %%
# DF VENTAS
df_ventas[["precio", "cantidad", "venta_unitaria"]].describe()
# Out:
#             precio     cantidad  venta_unitaria
# count  2998.000000  2998.000000     2998.000000
# mean     75.291318     6.502668      489.357412
# std      28.736008     3.455107      334.281817
# min      26.000000     1.000000       26.300000
# 25%      50.030000     3.000000      220.920000
# 50%      75.205000     7.000000      418.065000
# 75%     100.067500     9.000000      709.920000
# max     124.970000    12.000000     1488.120000

# %%
# DF MARKETING
df_marketing.head()
# Out:
#    id_campanha         producto  canal  costo fecha_inicio  fecha_fin
# 0           74  Adorno de pared     TV   4.81   2024-03-20 2024-05-03
# 1           12           Tablet   RRSS   3.40   2024-03-26 2024-05-13
# 2           32  Lámpara de mesa  Email   5.54   2024-03-28 2024-04-20
# 3           21       Smartphone   RRSS   6.37   2024-03-29 2024-05-16
# 4           58         Alfombra  Email   4.25   2024-03-31 2024-05-05

# %%
df_marketing.groupby("canal")["costo"].describe()
# Out:
#        count      mean       std   min     25%    50%     75%   max
# canal
# Email   30.0  4.840000  0.898773  2.95  4.2125  4.895  5.5075  6.84
# RRSS    30.0  5.030333  0.894101  3.16  4.5600  5.130  5.5425  7.16
# TV      30.0  4.915667  1.063215  3.06  4.3725  4.795  5.5400  7.39

# %% [markdown]
# EDA con gráficos

# %%
# Histograma de precios
# Estilo y tamaños
sns.set_theme(style="darkgrid", palette="deep") # deep, muted, bright, Set1, Set2, Set3
plt.figure(figsize=(8, 4))

# Graficamos
sns.histplot(data=df_ventas, x="precio", bins="auto", kde=True)

# Títulos y leyendas
plt.title("Histograma de precios")
plt.xlabel("Precio")
plt.ylabel("Frecuencia")
plt.show()

# %%
# Histograma de cantidades
# Estilo y tamaños
sns.set_theme(style="darkgrid", palette="deep") # deep, muted, bright, Set1, Set2, Set3
plt.figure(figsize=(8, 4))

# Graficamos
sns.histplot(data=df_ventas, x="cantidad", bins="auto", kde=True)

# Títulos y leyendas
plt.title("Histograma de cantidades")
plt.xlabel("Cantidad")
plt.ylabel("Frecuencia")
plt.show()

# %%
# Histograma de ventas totales

# Estilo y tamaños
sns.set_theme(style="darkgrid", palette="deep") # deep, muted, bright, Set1, Set2, Set3
plt.figure(figsize=(8, 4))

# Graficamos
sns.histplot(data=df_ventas, x="venta_unitaria", bins="auto", kde=True)

# Títulos y leyendas
plt.title("Histograma de ventas totales")
plt.xlabel("Ventas")
plt.ylabel("Frecuencia")
plt.show()

# %%
# Histograma de costo de marketing

# Estilo y tamaños
sns.set_theme(style="darkgrid", palette="deep") # deep, muted, bright, Set1, Set2, Set3
plt.figure(figsize=(8, 4))

# Graficamos
sns.histplot(data=df_marketing, x="costo", bins="auto", kde=True)

# Títulos y leyendas
plt.title("Histograma de precios")
plt.xlabel("Precio")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# BOXPLOT

# %%
# Ventas
# Estilo y tamaños
sns.set_theme(style="darkgrid", palette="deep") # deep, muted, bright, Set1, Set2, Set3
plt.figure(figsize=(10, 4)) #ancho x alto = resolucion

# Subplots, dividen al lienzo en partes
plt.subplot(1,3,1) # (1,3,1) => (1 fila, 3 columans, bloque 1)

# Subplot 1
sns.boxplot(data=df_ventas, y="precio")
plt.title("Boxplot de Precios")
plt.ylabel("")

# Subplot 2
plt.subplot(1,3,2) # (1,3,2) => (1 fila, 3 columans, bloque 2)
sns.boxplot(data=df_ventas, y="venta_unitaria")
plt.title("Boxplot de Valor de venta")
plt.ylabel("")


# Subplot 3
plt.subplot(1,3,3) # (1,3,3) => (1 fila, 3 columans, bloque 3)
sns.boxplot(data=df_ventas, y="cantidad")
plt.title("Boxplot de Cantidad")
plt.ylabel("")

plt.show()

# %%
# Marketing

# Estilo y tamaños
sns.set_theme(style="darkgrid", palette="Set3") # deep, muted, bright, Set1, Set2, Set3
plt.figure(figsize=(10, 4))

# Graficamos
sns.boxplot(data=df_marketing, x="canal", y="costo")
# sns.boxplot(data=df_marketing, y="costo") # asi grafico costo para todos los canales

# Título y subtítulo
plt.title("Distribución del costo por canal de marketing", fontsize=16, pad=15)

plt.xlabel("Canales de marketing", fontsize=12)
plt.ylabel("")

# Rotación y tamaño de labels del eje X
plt.xticks(rotation=45, fontsize=10)

plt.show()

# %% [markdown]
# CORRELACIÓN

# %%
# Variables numéricas
correlacion = df_ventas[['precio', 'cantidad', 'venta_unitaria']].corr()
print("\nMatriz de correlación:")
print(correlacion)
# Out:
# Matriz de correlación:
#                   precio  cantidad  venta_unitaria
# precio          1.000000 -0.002388        0.558846
# cantidad       -0.002388  1.000000        0.773009
# venta_unitaria  0.558846  0.773009        1.000000

# %%
# Gráfico de dispersión y línea de tendencia
plt.figure(figsize=(8,3))
plt.subplot(1,2,1)
sns.scatterplot(data=df_ventas, x="precio", y="cantidad")

# agrega una linea de regresion
sns.regplot(
    data=df_ventas,
    x="precio",
    y="venta_unitaria",
    color="steelblue",
    line_kws={"color": "darkred", "label": "Recta de regresión"}
)

plt.subplot(1,2,2)
sns.scatterplot(data=df_ventas, x="precio", y="venta_unitaria")
sns.regplot(
    data=df_ventas,
    x="precio",
    y="venta_unitaria",
    color="steelblue",
    line_kws={"color": "darkred", "label": "Recta de regresión"}
)


plt.show()

# %%
# Mapa de calor de la correlación
sns.heatmap(correlacion, annot=True, cmap="Blues") # cmap = Blues, Greens, rocket
plt.show()

# %% [markdown]
# CONSOLIDACIÓN DE DATOS

# %% [markdown]
# KPI importantes para el negocio:
# - Importe total de ventas concretado por mes
# - Cantidad de productos totales vendidos por mes
# - Volumen de venta por categorías
# - Impacto de la campaña de marketing en las ventas

# %%
# Ventas totales por mes
# Columna mes
df_ventas["mes"] = df_ventas["fecha_venta"].dt.month

# Agrupamos por mes y agregamos por venta_unitaria
ventas_mes = df_ventas.groupby("mes", as_index=False).agg(
    ventas_mes=("venta_unitaria", "sum")
)

ventas_mes.head()
# Out:
#    mes  ventas_mes
# 0    1   129604.99
# 1    2   118672.44
# 2    3   136779.15
# 3    4   128430.69
# 4    5   143727.25

# %% [markdown]
# Gráfico de líneas de la evolución de las ventas en el año

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Estilo
sns.set_theme(style="whitegrid", context="talk")
custom_palette = sns.color_palette("Set2") # Aqui pueden cambiar a "Set1", "Set2", "Set3"

# Tamaño del lienzo
plt.figure(figsize=(8,4))

# Graficamos
sns.lineplot(data=ventas_mes, x="mes", y="ventas_mes", label="Ventas mesuales" )

# Ticks (valores de eje)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

# Ajustes de título y ejes
plt.title('Ventas mensuales con marca de inicio de campaña', fontsize=14)
plt.xlabel('Mes', fontsize=12)
plt.ylabel('Ventas Acumuladas', fontsize=12)
plt.legend(title='Año', fontsize=10, title_fontsize=11)
plt.tight_layout()
plt.show()

# %% [markdown]
# Productos vendidos por mes

# %%
# Agrupamos por mes y agregamos por cantidad
cantidades_mes = df_ventas.groupby("mes", as_index=False).agg(
    cantidad_mes=("cantidad", "sum")
)

cantidades_mes.head()
# Out:
#    mes  cantidad_mes
# 0    1        1741.0
# 1    2        1607.0
# 2    3        1792.0
# 3    4        1715.0
# 4    5        1812.0

# %%
# Estilo y paleta
sns.set_theme(               # set_theme combina estilo + contexto + paleta
    style="whitegrid",       # opciones: 'white', 'whitegrid', 'dark', 'darkgrid', 'ticks'
    context="notebook",          # escala general: 'paper', 'notebook', 'talk', 'poster'
    palette="Set3"           # paleta de colores base: "deep", "muted", "pastel" / Set1, Set2, Set3
)

# Ajustamos tamaño del lienzo
plt.figure(figsize=(8,4))

# Crear el barplot
ax = sns.barplot(data=cantidades_mes, x='mes', y='cantidad_mes', label="Ventas 2024", width=0.8)

# Agregar etiquetas arriba de las barras
for i, valor in enumerate(cantidades_mes['cantidad_mes']):
    ax.text(
        i,                       # posición x de la etiqueta
        valor + 10,                   # posición y (ligeramente arriba de la barra)
        str(valor),              # texto
        ha='center', fontsize=8
    )

# Ticks (valores de eje)
plt.tick_params(axis='y', labelsize=7)
plt.tick_params(axis='x', rotation=45,  labelsize=7)

# Ajustes de título y ejes
plt.title('Volúmenes de ventas por productos', fontsize=12)
plt.xlabel('Mes')
plt.ylabel('Cantidades')
plt.legend(loc='upper right', fontsize=10)
# plt.tight_layout() # ajuste automatico
plt.show()
